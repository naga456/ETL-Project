# %%
import pandas as pd
import numpy as np
import os
# Out:
# C:\Users\wl030\Anaconda3\lib\site-packages\numpy\core\__init__.py:29: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\wl030\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.BNVRK7633HSX7YVO2TADGR4A5KEKXJAW.gfortran-win_amd64.dll
# C:\Users\wl030\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.CSRRD7HKRKC3T3YXA7VY7TAZGLSWDKW6.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
url2 = 'https://en.wikipedia.org/wiki/List_of_video_games_based_on_films'
tables2 = pd.read_html(url2)
tables2
# only use tables2[0]
# Out:
# [                                                  Name  Year  \
#  0                      3 Ninjas Kick Back (video game)  1994
#  1                                 007: Licence to Kill  1989
#  2                                          007 Legends  2012
#  3                102 Dalmatians: Puppies to the Rescue  2000
#  4                                  300: March to Glory  2007
#  5                      A Sound of Thunder (video game)  2004
#  6                                            A.D. 2044  1996
#  7                               Action Man: Robot Atak  2004
#  8                    Addams Family Values (video game)  1995
#  9                       The Addams Family (video game)  1992
#  10                               Æon Flux (video game)  2005
#  11                            Alex Rider: Stormbreaker  2006
#  12                              Alexander (video game)  2004
#  13               Alice in Wonderland (2000 video game)  2000
# ...

# %%
wl_df = tables2[0]

# %%
wl_df.head()
# Out:
#                                     Name  Year  \
# 0        3 Ninjas Kick Back (video game)  1994
# 1                   007: Licence to Kill  1989
# 2                            007 Legends  2012
# 3  102 Dalmatians: Puppies to the Rescue  2000
# 4                    300: March to Glory  2007
#
#                                Developer  \
# 0                     Malibu Interactive
# 1                                 Quixel
# 2                                Eurocom
# 3  Digital Eclipse (GBC) Toys for Bob[a]
# 4                      Collision Studios
#
#                                           Publisher  \
# 0                                    Sony Imagesoft
# 1                                            Domark
# 2                                        Activision
# 3  Eidos Interactive (PS1, PC, DC) Activision (GBC)
# 4                                Warner Bros. Games
#
#                                                 Film
# ...

# %%
test = wl_df.copy()

# %%
import re

# %%
wl_df_cleaned = wl_df.drop(columns="Developer")

# %%
wl_df_cleaned['Name'] = wl_df_cleaned['Name'].apply(lambda x: x.split('(')[0])

# %%
wl_df_cleaned.head()
# Out:
#                                     Name  Year  \
# 0                    3 Ninjas Kick Back   1994
# 1                   007: Licence to Kill  1989
# 2                            007 Legends  2012
# 3  102 Dalmatians: Puppies to the Rescue  2000
# 4                    300: March to Glory  2007
#
#                                           Publisher  \
# 0                                    Sony Imagesoft
# 1                                            Domark
# 2                                        Activision
# 3  Eidos Interactive (PS1, PC, DC) Activision (GBC)
# 4                                Warner Bros. Games
#
#                                                 Film
# 0                                 3 Ninjas Kick Back
# 1                                    Licence to Kill
# 2  Goldfinger, On Her Majesty's Secret Service, M...
# 3                                     102 Dalmatians
# 4                                                300

# %%
wl_df_cleaned['Publisher'].dtypes
# Out:
# dtype('O')

# %%
test = "Eidos Interactive (PS1, PC, DC) Activision (GBC)"
re.sub(r'\(([^\)]+)\)', '', test)
# Out:
# 'Eidos Interactive  Activision '

# %%
###wl - comment: code to strip brackets and words inbetween brackets
wl_df_cleaned['Publisher'] = wl_df_cleaned['Publisher'].apply(lambda x: re.sub(r'\(([^\)]+)\)', '', str(x)))

# %%
wl_df_cleaned['Publisher']
# Out:
# 0                                         Sony Imagesoft
# 1                                                 Domark
# 2                                             Activision
# 3                         Eidos Interactive  Activision
# 4                                     Warner Bros. Games
# 5                                     BAM! Entertainment
# 6                                              LK Avalon
# 7                                                  Atari
# 8                                         Ocean Software
# 9                                         Ocean Software
# 10                                 Majesco Entertainment
# 11                                                   THQ
# 12                                               Ubisoft
# 13                                              Nintendo
# 14                            Disney Interactive Studios
# 15                                              Epoch[1]
# ...

# %%
###wl - comment: code to strip brackets and words inbetween brackets
wl_df_cleaned['Publisher'] = wl_df_cleaned['Publisher'].apply(lambda x: re.sub(r'\[(.*?)\]', '', str(x)))
wl_df_cleaned['Publisher']
# Out:
# 0                                         Sony Imagesoft
# 1                                                 Domark
# 2                                             Activision
# 3                         Eidos Interactive  Activision
# 4                                     Warner Bros. Games
# 5                                     BAM! Entertainment
# 6                                              LK Avalon
# 7                                                  Atari
# 8                                         Ocean Software
# 9                                         Ocean Software
# 10                                 Majesco Entertainment
# 11                                                   THQ
# 12                                               Ubisoft
# 13                                              Nintendo
# 14                            Disney Interactive Studios
# 15                                                 Epoch
# ...

# %%
wl_df_cleaned.head()
# Out:
#                                     Name  Year  \
# 0                    3 Ninjas Kick Back   1994
# 1                   007: Licence to Kill  1989
# 2                            007 Legends  2012
# 3  102 Dalmatians: Puppies to the Rescue  2000
# 4                    300: March to Glory  2007
#
#                         Publisher  \
# 0                  Sony Imagesoft
# 1                          Domark
# 2                      Activision
# 3  Eidos Interactive  Activision
# 4              Warner Bros. Games
#
#                                                 Film
# 0                                 3 Ninjas Kick Back
# 1                                    Licence to Kill
# 2  Goldfinger, On Her Majesty's Secret Service, M...
# 3                                     102 Dalmatians
# 4                                                300

# %%
wl_df_cleaned.to_csv("list_of_videogames.csv")
